# %%
neurons_path = 'neurons.csv.gz'
connect_path = 'connections_princeton.csv.gz'

# %%
import pandas as pd
neurons_df = pd.read_csv(neurons_path, compression='gzip')
connect_df = pd.read_csv(connect_path, compression='gzip')

# %%
neurons_df
# Out:
#                    Root ID Top in/out region Community labels  \
# 0       720575940381905254           NO_CONS              NaN
# 1       720575940386709331           NO_CONS    soma in brain
# 2       720575940387110289           NO_CONS   sensory neuron
# 3       720575940389711170           NO_CONS              NaN
# 4       720575940407089948           NO_CONS              NaN
# ...                    ...               ...              ...
# 115146  720575941733218347          SAD.AVLP              NaN
# 115147  720575941733241899          SAD.AMMC              NaN
# 115148  720575941733258795              AMNP              NaN
# 115149  720575941733260075                ME    soma in brain
# 115150  720575941733281579         T2_MESONM              NaN
#
#        Predicted NT type  Predicted NT confidence Verified NT type  \
# 0                    NaN                      NaN              NaN
# 1                    NaN                      NaN              NaN
# ...

# %%
connect_df
# Out:
#                 pre_root_id        post_root_id          neuropil  syn_count  \
# 0        720575941350274352  720575941399414563    VNC_T1_ProNm_R         28
# 1        720575941350274352  720575941399414563  VNC_unassigned_R          2
# 2        720575941350274352  720575941409918831    VNC_T1_ProNm_R          3
# 3        720575941350274352  720575941425044820   VNC_T3_MetaNm_R          3
# 4        720575941350274352  720575941434753568   VNC_T2_MesoNm_R          9
# ...                     ...                 ...               ...        ...
# 3777041  720575941733281579  720575941617250431   VNC_T2_MesoNm_L          3
# 3777042  720575941733281579  720575941623072970   VNC_T2_MesoNm_L          5
# 3777043  720575941733281579  720575941640436255   VNC_T2_MesoNm_L          6
# 3777044  720575941733281579  720575941645063329   VNC_T2_MesoNm_L          5
# 3777045  720575941733281579  720575941686672246   VNC_T2_MesoNm_L          4
#
#          nt_type
# 0            NaN
# ...
