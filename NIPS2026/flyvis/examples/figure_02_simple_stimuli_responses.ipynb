# %% [markdown]
# # Figure 2

# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import numpy as np

from flyvis import EnsembleView
from flyvis.utils import color_utils
# Out:
# /data/scratch/projects/punim0477/yitai/NIPS2026/.venv/lib64/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))

# %%
ensemble = EnsembleView(
    "flow/0001",
    best_checkpoint_fn_kwargs={"validation_subdir": "validation", "loss_file_name": "loss"},
)
# Out:
# Loading ensemble:   0%|          | 0/1 [00:00<?, ?it/s]
# [2026-04-02 05:10:21] ensemble:166 Loaded 1 networks.

# %% [markdown]
# ## b

# %%
fig, ax = ensemble.flash_response_index()

ymin, ymax = 0, 1
# to get locations of left most and right most T4 subtype ticks
xmin, xmax = [
    p.get_position()[0] for p in ax.get_xticklabels() if p.get_text() in ["R1", "Tm3"]
]
# to place in between ticks
xmin -= 1 / 2
xmax += 1 / 2
xy = (xmin, ymin)
width = xmax - xmin
height = ymax
rect = Rectangle(xy, width, height, facecolor=color_utils.ON_FR, alpha=0.1)
ax.add_patch(rect)

ymin, ymax = 0, -1
# to get locations of left most and right most T4 subtype ticks
xmin, xmax = [
    p.get_position()[0] for p in ax.get_xticklabels() if p.get_text() in ["L1", "Tm9"]
]
# to place in between ticks
xmin -= 1 / 2
xmax += 1 / 2
xy = (xmin, ymin)
width = xmax - xmin
height = ymax
rect = Rectangle(xy, width, height, facecolor=color_utils.OFF_FR, alpha=0.1)
ax.add_patch(rect)

ax.set_title("Flash response indices")
# Out:
# /data/scratch/projects/punim0477/yitai/NIPS2026/flyvis/data/results/flow/0001/000/__cache__/flyvis/analysis/stimulus_responses/compute_responses/afb6ca48c465d83639dcd0aa4684550b/output.h5
# Text(0.5, 1.0, 'Flash response indices')

# %% [markdown]
# ## c

# %%
fig, axes = ensemble.direction_selectivity_index()

ymin, ymax = 0, 1
# to get locations of left most and right most T4 subtype ticks
xmin, xmax = [
    p.get_position()[0]
    for p in axes[1].get_xticklabels()
    if p.get_text() in ["T4a", "T4d"]
]
# to place in between ticks
xmin -= 1 / 2
xmax += 1 / 2
xy = (xmin, ymin)
width = xmax - xmin
height = ymax
rect = Rectangle(xy, width, height, facecolor=color_utils.ON, alpha=0.1)
axes[0].add_patch(rect)

# to get locations of left most and right most T4 subtype ticks
xmin, xmax = [
    p.get_position()[0]
    for p in axes[1].get_xticklabels()
    if p.get_text() in ["T5a", "T5d"]
]
# to place in between ticks
xmin -= 1 / 2
xmax += 1 / 2
xy = (xmin, ymin)
width = xmax - xmin
height = ymax
rect = Rectangle(xy, width, height, facecolor=color_utils.OFF, alpha=0.1)
axes[1].add_patch(rect)

ax.set_title("Direction selectivity indices")
# Out:
# [2026-04-02 05:11:39] network:222 Initialized network with NumberOfParams(free=734, fixed=2959) parameters.
# [2026-04-02 05:11:39] chkpt_utils:36 Recovered network state.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 fig, axes = ensemble.direction_selectivity_index()
#       3 ymin, ymax = 0, 1
#       4 # to get locations of left most and right most T4 subtype ticks
#
# File /data/scratch/projects/punim0477/yitai/NIPS2026/flyvis/flyvis/network/ensemble_view.py:269, in EnsembleView.direction_selectivity_index(self, **kwargs)
#     257 @wraps(dsi_violins_on_and_off)
#     258 def direction_selectivity_index(
#     259     self, **kwargs
#     260 ) -> Tuple[plt.Figure, Tuple[plt.Axes, plt.Axes]]:
#     261     """Plot the direction selectivity indices of the ensemble.
#     262
#     263     Args:
#    (...)
#     267         A tuple containing the matplotlib Figure and a tuple of Axes objects.
#     268     """
# --> 269     responses = self.moving_edge_responses()
#     270     dsis = direction_selectivity_index(responses)
#     271     task_error = self.task_error()
#
# File /data/scratch/projects/punim0477/yitai/NIPS2026/flyvis/flyvis/utils/cache_utils.py:41, in context_aware_cache.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      39 if cache_key in self.cache:
#      40     return self.cache[cache_key]
# ---> 41 result = f(self, *args, **kwargs)
#      42 self.cache[cache_key] = result
#      43 return result
#
# File /data/scratch/projects/punim0477/yitai/NIPS2026/flyvis/flyvis/network/ensemble.py:741, in Ensemble.moving_edge_responses(self, *args, **kwargs)
#     737 @wraps(stimulus_responses.moving_edge_responses)
#     738 @context_aware_cache(context=lambda self: (self.names))
#     739 def moving_edge_responses(self, *args, **kwargs) -> xr.Dataset:
#     740     """Generate moving edge responses."""
# --> 741     return stimulus_responses.moving_edge_responses(self, *args, **kwargs)
#
# File /data/scratch/projects/punim0477/yitai/NIPS2026/flyvis/flyvis/analysis/stimulus_responses.py:311, in moving_edge_responses(network_view_or_ensemble, dataset, speeds, offsets, dt, batch_size)
#     292 def moving_edge_responses(
#     293     network_view_or_ensemble: Union["flyvis.NetworkView", "flyvis.network.Ensemble"],
#     294     dataset: Optional[MovingEdge] = None,
#    (...)
#     298     batch_size=4,
#     299 ) -> xr.Dataset:
#     300     default_dataset_config = {
#     301         'offsets': offsets,
#     302         'intensities': [0, 1],
#    (...)
#     309         't_post': 1.0,
#     310     }
# --> 311     return generic_responses(
#     312         network_view_or_ensemble,
#     313         dataset,
#     314         default_dataset_config,
#     315         MovingEdge,
#     316         t_pre=1.0,
#     317         t_fade_in=0.0,
#     318         batch_size=batch_size,
#     319     )
#
# File /data/scratch/projects/punim0477/yitai/NIPS2026/flyvis/flyvis/analysis/stimulus_responses.py:186, in generic_responses(network_view_or_ensemble, dataset, dataset_config, default_dataset_cls, t_pre, t_fade_in, batch_size, cell_index)
#     183     checkpoints.append(checkpointed_network.checkpoint)
#     184     return checkpointed_network.network
# --> 186 network = handle_network(0, network_views[0], None)
#     188 for idx, network_view in enumerate(network_views[1:], 1):
#     189     network = handle_network(idx, network_view, network)
#
# File /data/scratch/projects/punim0477/yitai/NIPS2026/flyvis/flyvis/analysis/stimulus_responses.py:173, in generic_responses.<locals>.handle_network(idx, network_view, network)
#     169     checkpointed_network.init()
#     171 # Call the cached compute_responses function
#     172 results.append(
# --> 173     cached_compute_responses_fn(
#     174         checkpointed_network,
#     175         dataset_class,
#     176         dataset_config,
#     177         batch_size,
#     178         t_pre,
#     179         t_fade_in,
#     180         cell_index,
#     181     )  # type: xr.Dataset
#     182 )
#     183 checkpoints.append(checkpointed_network.checkpoint)
#     184 return checkpointed_network.network
#
# File /data/scratch/projects/punim0477/yitai/NIPS2026/.venv/lib64/python3.9/site-packages/joblib/memory.py:607, in MemorizedFunc.__call__(self, *args, **kwargs)
#     605 def __call__(self, *args, **kwargs):
#     606     # Return the output, without the metadata
# --> 607     return self._cached_call(args, kwargs, shelving=False)[0]
#
# File /data/scratch/projects/punim0477/yitai/NIPS2026/.venv/lib64/python3.9/site-packages/joblib/memory.py:562, in MemorizedFunc._cached_call(self, args, kwargs, shelving)
#     556     self.warn(
#     557         f"Computing func {func_name}, argument hash {args_id} "
#     558         f"in location {location}"
#     559     )
#     561 # Returns the output but not the metadata
# --> 562 return self._call(call_id, args, kwargs, shelving)
#
# File /data/scratch/projects/punim0477/yitai/NIPS2026/.venv/lib64/python3.9/site-packages/joblib/memory.py:832, in MemorizedFunc._call(self, call_id, args, kwargs, shelving)
#     830 self._before_call(args, kwargs)
#     831 start_time = time.time()
# --> 832 output = self.func(*args, **kwargs)
#     833 return self._after_call(call_id, args, kwargs, shelving, output, start_time)
#
# File /data/scratch/projects/punim0477/yitai/NIPS2026/flyvis/flyvis/analysis/stimulus_responses.py:52, in compute_responses(network, dataset_class, dataset_config, batch_size, t_pre, t_fade_in, cell_index)
#      49 network = network.network  # type: flyvis.Network
#      51 # Initialize dataset
# ---> 52 dataset = dataset_class(**dataset_config)
#      54 if cell_index == "central":
#      55     # Prepare central cells index
#      56     cell_index = network.connectome.central_cells_index[:]
#
# File /data/scratch/projects/punim0477/yitai/NIPS2026/flyvis/flyvis/datasets/moving_bar.py:679, in MovingEdge.__init__(self, offsets, intensities, speeds, height, dt, device, post_pad_mode, t_pre, t_post, build_stim_on_init, shuffle_offsets, seed, angles, **kwargs)
#     662 def __init__(
#     663     self,
#     664     offsets: tuple[int, int] = (-10, 11),
#    (...)
#     677     **kwargs,
#     678 ) -> None:
# --> 679     super().__init__(
#     680         widths=[80],
#     681         offsets=offsets,
#     682         intensities=intensities,
#     683         speeds=speeds,
#     684         height=height,
#     685         dt=dt,
#     686         device=device,
#     687         bar_loc_horizontal=np.radians(0),
#     688         post_pad_mode=post_pad_mode,
#     689         t_pre=t_pre,
#     690         t_post=t_post,
#     691         build_stim_on_init=build_stim_on_init,
#     692         shuffle_offsets=shuffle_offsets,
#     693         seed=seed,
#     694         angles=angles,
#     695     )
#
# File /data/scratch/projects/punim0477/yitai/NIPS2026/flyvis/flyvis/datasets/moving_bar.py:240, in MovingBar.__init__(self, widths, offsets, intensities, speeds, height, dt, device, bar_loc_horizontal, post_pad_mode, t_pre, t_post, build_stim_on_init, shuffle_offsets, seed, angles)
#     238 self._built = False
#     239 if build_stim_on_init:
# --> 240     self._build()
#     241     self._resample()
#     242     self._built = True
#
# File /data/scratch/projects/punim0477/yitai/NIPS2026/flyvis/flyvis/datasets/moving_bar.py:285, in MovingBar._build(self)
#     283 def _build(self) -> None:
#     284     """Build the stimulus."""
# --> 285     self.wrap = RenderedOffsets(
#     286         dict(
#     287             angles=self.angles,
#     288             widths=self.widths,
#     289             intensities=self.intensities,
#     290             offsets=self.offsets,
#     291             led_width=self.led_width,
#     292             height=self.height,
#     293             n_bars=self.n_bars,
#     294             bg_intensity=self.bg_intensity,
#     295             bar_loc_horizontal=self.bar_loc_horizontal,
#     296         )
#     297     )
#     299     self._offsets = torch.tensor(self.wrap.offsets[:], device=self.device)
#     300     self._built = True
#
# File /data/scratch/projects/punim0477/yitai/NIPS2026/.venv/lib64/python3.9/site-packages/datamate/directory.py:124, in NonExistingDirectory.__call__(cls, *args, **kwargs)
#     123 def __call__(cls, *args, **kwargs):
# --> 124     return cls.__new__(cls, *args, **kwargs)
#
# File /data/scratch/projects/punim0477/yitai/NIPS2026/.venv/lib64/python3.9/site-packages/datamate/context.py:129, in root.<locals>.decorator.<locals>.function(*args, **kwargs)
#     121 if root_dir is not None and (
#     122     precedence == 3
#     123     or (precedence == 2 and not within_context)
#     124     or precedence == 1
#     125     and not within_context
#     126 ):
#     127     set_root_dir(root_dir)
# --> 129 _return = new(*args, **kwargs)
#     130 set_root_dir(_root_dir)
#     131 return _return
#
# File /data/scratch/projects/punim0477/yitai/NIPS2026/.venv/lib64/python3.9/site-packages/datamate/directory.py:255, in Directory.__new__(_type, *args, **kwargs)
#     253     cls = _directory_from_path(cls, _resolve_path(path))
#     254 elif path is None and config is not None:
# --> 255     cls = _directory_from_config(cls, config)
#     256 elif path is not None and config is not None:
#     257     cls = _directory_from_path_and_config(cls, _resolve_path(path), config)
#
# File /data/scratch/projects/punim0477/yitai/NIPS2026/.venv/lib64/python3.9/site-packages/datamate/directory.py:1409, in _directory_from_config(cls, conf)
#    1406     continue
#    1408 while meta.status == "running":
# -> 1409     sleep(1.0)
#    1410     meta = read_meta(path)
#    1411 if meta.status == "done":
#
# KeyboardInterrupt:

# %% [markdown]
# ## d

# %%
from flyvis.analysis.flash_responses import (
    flash_response_index,
    fri_correlation_to_known,
)
from flyvis.analysis.moving_bar_responses import (
    direction_selectivity_index,
    dsi_correlation_to_known,
    correlation_to_known_tuning_curves,
    preferred_direction,
    angular_distance_to_known,
)

# %%
print(ensemble.names)
fris = flash_response_index(ensemble.flash_responses(), radius=6)
fri_corr = fri_correlation_to_known(fris)
# Out:
# ['flow/0001/000']

# %%
stims_and_resps_moving_edges = ensemble.moving_edge_responses()

# # TODO: fix this, does not come out as expected
# dsi_corr = dsi_correlation_to_known(
#     direction_selectivity_index(stims_and_resps_moving_edges)
# )
# tuning_corrs = correlation_to_known_tuning_curves(stims_and_resps_moving_edges)
# t4_corrs = (
#     tuning_corrs.custom.where(cell_type=["T4a", "T4b", "T4c", "T4d"], intensity=1)
#     .median("neuron")
#     .squeeze()
# )
# t5_corrs = (
#     tuning_corrs.custom.where(cell_type=["T5a", "T5b", "T5c", "T5d"], intensity=0)
#     .median("neuron")
#     .squeeze()
# )
# Out:
# [2026-04-02 05:14:15] chkpt_utils:36 Recovered network state.

# %%
pds = preferred_direction(stims_and_resps_moving_edges)
pd_distances = angular_distance_to_known(pds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 pds = preferred_direction(stims_and_resps_moving_edges)
#       2 pd_distances = angular_distance_to_known(pds)
#
# NameError: name 'stims_and_resps_moving_edges' is not defined

# %%
from flyvis.analysis.visualization.plots import violin_groups

fig, ax, *_ = violin_groups(
    np.stack(
        [
            fri_corr.squeeze(),
            t4_corrs.values,
            t5_corrs.values,
            dsi_corr.values,
        ],
        axis=0,
    )[:, None, :],
    ["FRI", "T4 tuning", "T5 tuning", "DSI"],
    ylabel="correlation",
    figsize=(1.8, 1.5),
    ylim=(-1, 1),
    colors=[
        plt.get_cmap("Dark2")(0.125),
        plt.get_cmap("Dark2")(0),
        plt.get_cmap("Dark2")(0.25),
        plt.get_cmap("Dark2")(0.375),
    ],
    color_by="experiments",
    scatter_edge_color="gray",
    scatter_radius=5,
    violin_alpha=0.8,
)

# %%
fig, ax, *_ = violin_groups(
    pd_distances.values.flatten()[None, None, :],
    ["PD distance"],
    ylabel="angular distance",
    figsize=(1.8, 1.5),
    ylim=(-1, 1),
    colors=[
        plt.get_cmap("Dark2")(0.5),
    ],
    color_by="experiments",
    scatter_edge_color="gray",
    scatter_radius=5,
    violin_alpha=0.8,
)
ax.set_ylim(
    np.pi + 0.1,
    -0.1,
)
